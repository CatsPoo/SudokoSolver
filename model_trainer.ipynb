# %%
import os
import pandas as pd
import DigitRecognizer.DigitRecognizerModelTrainer as dr
import pickle
import numpy as np

# %%
X,y = dr.build_dataset(os.path.join('DigitRecognizer','assets'))

# %%
X.shape
# Out:
# (7918, 28, 28)

# %%
y.shape
# Out:
# (7918,)

# %%
pipe = dr.generate_model_pipeline()
# Out:
# g:\האחסון שלי\Projects\SudokoSolver\sudukosolver\venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
pipe.fit(X,y)
# Out:
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# ...

# %%
# best_model_pipe = dr.get_best_model_pipeline(pipes)

# Open a file in write mode
with open('fitted-model.pickle', 'wb') as file:
    # Serialize and save the object to the file
    pickle.dump(pipe, file)

# %%
from SudokoSolver.ImageUtils import image_to_vector
vectorsArr = []
vectorsArr.append(image_to_vector('./DigitRecognizer/assets/5/0_0_2515.jpeg'))
vectorsArr.append(image_to_vector('./DigitRecognizer/assets/0/176_72.jpg'))
vectorsArr.append(image_to_vector('./DigitRecognizer/assets/9/0_0_1697.jpeg'))
vectorsArr.append(image_to_vector('./test_image.jpg'))

vectorsArr = np.array(vectorsArr)
vectorsArr[-1] = 1 - vectorsArr[-1]

# %%
prediction = pipe.predict(vectorsArr)
# Out:
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# @@@@@
# (28, 28)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
